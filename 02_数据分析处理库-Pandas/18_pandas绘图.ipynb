# %%
# %matplotlib inline
import pandas as pd

# %%
import numpy as np

s = pd.Series(np.random.randn(10),index = np.arange(0,100,10)) #10个一蹦
print(s,'\n',s.shape)
s.plot() #直接画图
# Out:
# 0    -0.936348
# 10   -2.261165
# 20   -0.808207
# 30   -1.187940
# 40    0.319168
# 50    0.312853
# 60    0.924571
# 70   -0.224264
# 80    0.231380
# 90    1.352754
# dtype: float64
#  (10,)

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0), 
               index = np.arange(0, 100, 10), 
               columns = ['A', 'B', 'C', 'D'])
df.head()
# Out:
#            A         B         C         D
# 0   0.101783 -0.623238  1.707105  0.679547
# 10 -0.892272 -0.813715  1.539008  0.429693
# 20 -1.890263 -0.532736  1.639769  0.987356
# 30 -1.650016 -0.016945  1.933918 -1.790783
# 40 -2.325464  0.994255  1.964377  0.275321

# %%
df.plot()

# %%
import matplotlib.pyplot as plt

fig,axes = plt.subplots(2,1)
data = pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot(ax = axes[0],kind='bar')
data.plot(ax = axes[1],kind='barh')

# %%
df = pd.DataFrame(np.random.rand(6, 4), 
               index = ['one', 'two', 'three', 'four', 'five', 'six'], 
               columns = pd.Index(['A', 'B', 'C', 'D'], name = 'Genus'))
df.head()
# Out:
# Genus         A         B         C         D
# one    0.632125  0.346379  0.234634  0.619464
# two    0.087636  0.331460  0.106358  0.053405
# three  0.055425  0.111788  0.372559  0.890295
# four   0.990309  0.425534  0.570903  0.924117
# five   0.076313  0.612586  0.151371  0.272863

# %%
df.plot(kind='bar')

# %%
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.total_bill.plot(kind='hist',bins=50)

# %%
macro = pd.read_csv('macrodata.csv')
macro.head()
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
data = macro[['quarter','realgdp','realcons']]

# %%
data.plot.scatter('quarter','realgdp')

# %%
pd.plotting.scatter_matrix(data,color='g',alpha=0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11aeb1fa0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b00b370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b0347f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b05dc40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b08a130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b0bf460>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b0bf550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b0e97f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b1410a0>]],
#       dtype=object)
